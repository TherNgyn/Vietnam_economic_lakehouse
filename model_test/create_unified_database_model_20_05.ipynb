# %% [markdown]
# # Chuyển Đổi Dữ Liệu Thành Unified Dataset
# ## Chi Tiết Từng File Dữ Liệu & Thống Kê
#
# Notebook này:
# - **Đọc** 24 file CSV từ `data/raw/`
# - **Kiểm tra** chi tiết từng file (rows, columns, date range)
# - **Tạo** unified dataset với 360 tháng (1995-2024)
# - **Xử lý** missing values (2,633 → 0)
# - **Xuất** chỉ 1 file đầu ra: `cpi_forecast_full_dataset_advanced.csv`

# %% [markdown]
# ## Setup & Chuẩn Bị

# %%
import pandas as pd
import numpy as np
import os
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')
script_dir = os.path.abspath('') 

data_raw_dir = os.path.join(script_dir, 'data', 'raw')
data_processed_dir = os.path.join(script_dir, 'data', 'processed')

os.makedirs(data_raw_dir, exist_ok=True)
os.makedirs(data_processed_dir, exist_ok=True)

print(f"{script_dir}")
# Out:
# d:\Nam4-HK1\KLTN\Vietnam_economic_lakehouse\model_test

# %% [markdown]
# ## BƯỚC 1: Chi Tiết Từng File Dữ Liệu

# %% [markdown]
# Bỏ 2018 + gasoline

# %%
data_config = {
    # Economic
    'cpi_mom_processed.csv': {'date_col': 'date', 'value_cols': ['cpi', 'inflation'], 'category': 'Economic'},
    'core_inflation_rate.csv': {'date_col': 'date', 'value_cols': ['value'], 'category': 'Economic'},
    #'cpi_base_year.csv': {'date_col': 'date', 'value_cols': ['base_2010'], 'category': 'Economic'},
    'interest_rate.csv': {'date_col': 'date', 'value_cols': ['interest_rate'], 'category': 'Economic', 'filter_term': '3 Months'},
    'ppi_qoq.csv': {'date_col': 'date', 'value_cols': ['value'], 'category': 'Economic'},
    'm2.csv': {'date_col': 'date', 'value_cols': ['value'], 'category': 'Economic'},
    'broad_money.csv': {'date_col': 'date', 'value_cols': ['value'], 'category': 'Economic'},
    'policy_rate.csv': {'date_col': 'date', 'value_cols': ['value'], 'category': 'Economic'},
    'gdp.csv': {'date_col': 'date', 'value_cols': ['value'], 'category': 'Economic'},

    # Commodities
    'brent.csv': {'date_col': 'date', 'value_cols': ['close'], 'category': 'Commodity'},
    'wti.csv': {'date_col': 'date', 'value_cols': ['close'], 'category': 'Commodity'},
    #'gasoline.csv': {'date_col': 'date', 'value_cols': ['price'], 'category': 'Commodity', 'filter_product': 'RON 95'},
    'gasoline_world.csv': {'date_col': 'date', 'value_cols': ['close'], 'category': 'Commodity'},
    'natural_gas.csv': {'date_col': 'date', 'value_cols': ['close'], 'category': 'Commodity'},
    'gold.csv': {'date_col': 'date', 'value_cols': ['close'], 'category': 'Commodity'},
    'silver.csv': {'date_col': 'date', 'value_cols': ['close'], 'category': 'Commodity'},
    
    # Vietnam stocks
    'VNINDEX.csv': {'date_col': 'date', 'value_cols': ['close'], 'category': 'VN_Stock'},
    'VN30.csv': {'date_col': 'date', 'value_cols': ['close'], 'category': 'VN_Stock'},
    'HNX.csv': {'date_col': 'date', 'value_cols': ['close'], 'category': 'VN_Stock'},
    'UPCOM.csv': {'date_col': 'date', 'value_cols': ['close'], 'category': 'VN_Stock'},
    
    # Global stocks
    'NASDAQ.csv': {'date_col': 'date', 'value_cols': ['close'], 'category': 'Global_Stock'},
    'S&P500.csv': {'date_col': 'date', 'value_cols': ['close'], 'category': 'Global_Stock'},
    'DAX.csv': {'date_col': 'date', 'value_cols': ['close'], 'category': 'Global_Stock'},
    'DOWJONES.csv': {'date_col': 'date', 'value_cols': ['close'], 'category': 'Global_Stock'},
    'NIKKEI225.csv': {'date_col': 'date', 'value_cols': ['close'], 'category': 'Global_Stock'},
    'HANGSENG.csv': {'date_col': 'date', 'value_cols': ['close'], 'category': 'Global_Stock'},
    
    # Currency
    'USDVND.csv': {'date_col': 'date', 'value_cols': ['close'], 'category': 'Currency'},
}

# %% [markdown]
# ## BƯỚC 2: Tải & Kiểm Tra Chi Tiết

# %%
loaded_data = {}
file_details = []
failed = []

for filename in sorted(os.listdir(data_raw_dir)):
    if not filename.endswith('.csv'):
        continue
    
    try:
        filepath = os.path.join(data_raw_dir, filename)
        df = pd.read_csv(filepath)
        file_size = os.path.getsize(filepath) / 1024
        print(f"FILE: {filename}")
        print(f"Total rows: {len(df)}")
        print(f"Columns ({len(df.columns)}): {list(df.columns)}")
        # tỷ lệ null
        print("Null values (%):")
        print((df.isnull().mean() * 100).round(2))
        print(df.head())

        date_col = None
        if 'date' in df.columns:
            date_col = 'date'
        else:
            for col in df.columns:
                try:
                    test = pd.to_datetime(df[col].iloc[:10], errors='coerce')
                    if test.notna().sum() > 5:
                        date_col = col
                        print(f"Auto-detected date column: '{date_col}'")
                        break
                except:
                    continue
        
        if date_col is None:
            failed.append((filename, "No date column detected"))
            continue

        df[date_col] = pd.to_datetime(df[date_col], errors='coerce')
        
        value_cols = [col for col in df.columns if col != date_col]
        print(f"Value columns to use ({len(value_cols)}): {value_cols}")

    except Exception as e:
        failed.append((filename, str(e)))
        print(f"ERROR: {str(e)[:80]}")
# Out:
# FILE: DAX.csv
# Total rows: 9683
# Columns (13): ['date', 'symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'prev_close', 'change', 'source']
# Null values (%):
# date                0.0
# symbol              0.0
# asset_class         0.0
# unit                0.0
# open                0.0
# high                0.0
# low                 0.0
# close               0.0
# volume              0.0
# change_percent      0.0
# prev_close        100.0
# change            100.0
# source              0.0
# dtype: float64
#          date symbol asset_class unit         open         high          low  \
# 0  1987-12-30    DAX       index  EUR  1005.190002  1005.190002  1005.190002
# 1  1988-01-04    DAX       index  EUR   956.489990   956.489990   956.489990
# 2  1988-01-05    DAX       index  EUR   996.099976   996.099976   996.099976
# 3  1988-01-06    DAX       index  EUR  1006.010010  1006.010010  1006.010010
# 4  1988-01-07    DAX       index  EUR  1014.469971  1014.469971  1014.469971
#
#          close  volume  change_percent  prev_close  change          source
# 0  1005.190002       0        0.000000         NaN     NaN  historical_csv
# 1   956.489990       0       -4.844856         NaN     NaN  historical_csv
# 2   996.099976       0        4.141181         NaN     NaN  historical_csv
# 3  1006.010010       0        0.994883         NaN     NaN  historical_csv
# 4  1014.469971       0        0.840942         NaN     NaN  historical_csv
# Value columns to use (12): ['symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'prev_close', 'change', 'source']
# FILE: DOWJONES.csv
# Total rows: 8634
# Columns (13): ['date', 'symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'prev_close', 'change', 'source']
# Null values (%):
# date                0.0
# symbol              0.0
# asset_class         0.0
# unit                0.0
# open                0.0
# high                0.0
# low                 0.0
# close               0.0
# volume              0.0
# change_percent      0.0
# prev_close        100.0
# change            100.0
# source              0.0
# dtype: float64
#          date    symbol asset_class unit         open         high  \
# 0  1992-01-02  DOWJONES       index  USD  3152.100098  3172.629883
# 1  1992-01-03  DOWJONES       index  USD  3172.399902  3210.639893
# 2  1992-01-06  DOWJONES       index  USD  3201.500000  3213.330078
# 3  1992-01-07  DOWJONES       index  USD  3200.100098  3210.199951
# 4  1992-01-08  DOWJONES       index  USD  3204.800049  3229.199951
#
#            low        close    volume  change_percent  prev_close  change  \
# 0  3139.310059  3172.399902  23550000        0.000000         NaN     NaN
# 1  3165.919922  3201.500000  23620000        0.917290         NaN     NaN
# 2  3191.860107  3200.100098  27280000       -0.043726         NaN     NaN
# 3  3184.479980  3204.800049  25510000        0.146869         NaN     NaN
# 4  3185.820068  3203.899902  29040000       -0.028087         NaN     NaN
#
#            source
# 0  historical_csv
# 1  historical_csv
# 2  historical_csv
# 3  historical_csv
# 4  historical_csv
# Value columns to use (12): ['symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'prev_close', 'change', 'source']
# FILE: HANGSENG.csv
# Total rows: 9696
# Columns (13): ['date', 'symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'prev_close', 'change', 'source']
# Null values (%):
# date                0.0
# symbol              0.0
# asset_class         0.0
# unit                0.0
# open                0.0
# high                0.0
# low                 0.0
# close               0.0
# volume              0.0
# change_percent      0.0
# prev_close        100.0
# change            100.0
# source              0.0
# dtype: float64
#          date    symbol asset_class unit         open         high  \
# 0  1986-12-31  HANGSENG       index  HKD  2568.300049  2568.300049
# 1  1987-01-02  HANGSENG       index  HKD  2540.100098  2540.100098
# 2  1987-01-05  HANGSENG       index  HKD  2552.399902  2552.399902
# 3  1987-01-06  HANGSENG       index  HKD  2583.899902  2583.899902
# 4  1987-01-07  HANGSENG       index  HKD  2607.100098  2607.100098
#
#            low        close  volume  change_percent  prev_close  change  \
# 0  2568.300049  2568.300049       0        0.000000         NaN     NaN
# 1  2540.100098  2540.100098       0       -1.098001         NaN     NaN
# 2  2552.399902  2552.399902       0        0.484225         NaN     NaN
# 3  2583.899902  2583.899902       0        1.234133         NaN     NaN
# 4  2607.100098  2607.100098       0        0.897875         NaN     NaN
#
#            source
# 0  historical_csv
# 1  historical_csv
# 2  historical_csv
# 3  historical_csv
# 4  historical_csv
# Value columns to use (12): ['symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'prev_close', 'change', 'source']
# FILE: HNX.csv
# Total rows: 5071
# Columns (12): ['date', 'symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'change', 'source']
# Null values (%):
# date                0.0
# symbol              0.0
# asset_class         0.0
# unit                0.0
# open                0.0
# high                0.0
# low                 0.0
# close               0.0
# volume              0.0
# change_percent      0.0
# change            100.0
# source              0.0
# dtype: float64
#          date symbol    asset_class   unit   open    high    low  close  \
# 0  2005-07-18    HNX  vietnam_index  point  99.48  100.79  99.48  99.48
# 1  2005-07-20    HNX  vietnam_index  point  95.57  103.25  95.57  95.57
# 2  2005-07-22    HNX  vietnam_index  point  97.46   97.46  94.52  97.46
# 3  2005-07-25    HNX  vietnam_index  point  96.51   97.31  96.10  96.51
# 4  2005-07-27    HNX  vietnam_index  point  98.00   98.02  97.38  98.00
#
#    volume  change_percent  change   source
# 0    30.0        0.000000     NaN  scraped
# 1   250.0       -3.930438     NaN  scraped
# 2    20.0        1.977608     NaN  scraped
# 3    10.0       -0.974759     NaN  scraped
# 4    20.0        1.543881     NaN  scraped
# Value columns to use (11): ['symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'change', 'source']
# FILE: HNX30.csv
# Total rows: 159
# Columns (12): ['date', 'symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'change', 'source']
# Null values (%):
# date                0.0
# symbol              0.0
# asset_class         0.0
# unit                0.0
# open                0.0
# high                0.0
# low                 0.0
# close               0.0
# volume              0.0
# change_percent      0.0
# change            100.0
# source              0.0
# dtype: float64
#          date symbol    asset_class   unit    open    high     low   close  \
# 0  2024-08-09  HNX30  vietnam_index  point  485.52  494.87  484.42  494.80
# 1  2024-08-12  HNX30  vietnam_index  point  489.10  501.28  489.10  501.28
# 2  2024-08-13  HNX30  vietnam_index  point  500.22  502.98  494.57  500.25
# 3  2024-08-14  HNX30  vietnam_index  point  495.51  503.96  491.82  498.88
# 4  2024-08-15  HNX30  vietnam_index  point  498.88  499.32  490.78  493.53
#
#     volume  change_percent  change   source
# 0  36310.0        0.000000     NaN  scraped
# 1  27720.0        1.309620     NaN  scraped
# 2  29800.0       -0.205474     NaN  scraped
# 3  28350.0       -0.273863     NaN  scraped
# 4  20150.0       -1.072402     NaN  scraped
# Value columns to use (11): ['symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'change', 'source']
# FILE: NASDAQ.csv
# Total rows: 13916
# Columns (13): ['date', 'symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'prev_close', 'change', 'source']
# Null values (%):
# date                0.0
# symbol              0.0
# asset_class         0.0
# unit                0.0
# open                0.0
# high                0.0
# low                 0.0
# close               0.0
# volume              0.0
# change_percent      0.0
# prev_close        100.0
# change            100.0
# source              0.0
# dtype: float64
#          date  symbol asset_class unit        open        high         low  \
# 0  1971-02-05  NASDAQ       index  USD  100.000000  100.000000  100.000000
# 1  1971-02-08  NASDAQ       index  USD  100.839996  100.839996  100.839996
# 2  1971-02-09  NASDAQ       index  USD  100.760002  100.760002  100.760002
# 3  1971-02-10  NASDAQ       index  USD  100.690002  100.690002  100.690002
# 4  1971-02-11  NASDAQ       index  USD  101.449997  101.449997  101.449997
#
#         close  volume  change_percent  prev_close  change          source
# 0  100.000000       0        0.000000         NaN     NaN  historical_csv
# 1  100.839996       0        0.839996         NaN     NaN  historical_csv
# 2  100.760002       0       -0.079328         NaN     NaN  historical_csv
# 3  100.690002       0       -0.069472         NaN     NaN  historical_csv
# 4  101.449997       0        0.754786         NaN     NaN  historical_csv
# Value columns to use (12): ['symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'prev_close', 'change', 'source']
# FILE: NIKKEI225.csv
# Total rows: 15067
# Columns (13): ['date', 'symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'prev_close', 'change', 'source']
# Null values (%):
# date                0.0
# symbol              0.0
# asset_class         0.0
# unit                0.0
# open                0.0
# high                0.0
# low                 0.0
# close               0.0
# volume              0.0
# change_percent      0.0
# prev_close        100.0
# change            100.0
# source              0.0
# dtype: float64
#          date     symbol asset_class unit         open         high  \
# 0  1965-01-05  NIKKEI225       index  JPY  1257.719971  1257.719971
# 1  1965-01-06  NIKKEI225       index  JPY  1263.989990  1263.989990
# 2  1965-01-07  NIKKEI225       index  JPY  1274.270020  1274.270020
# 3  1965-01-08  NIKKEI225       index  JPY  1286.430054  1286.430054
# 4  1965-01-12  NIKKEI225       index  JPY  1288.540039  1288.540039
#
#            low        close  volume  change_percent  prev_close  change  \
# 0  1257.719971  1257.719971       0        0.000000         NaN     NaN
# 1  1263.989990  1263.989990       0        0.498523         NaN     NaN
# 2  1274.270020  1274.270020       0        0.813300         NaN     NaN
# 3  1286.430054  1286.430054       0        0.954275         NaN     NaN
# 4  1288.540039  1288.540039       0        0.164019         NaN     NaN
#
#            source
# 0  historical_csv
# 1  historical_csv
# 2  historical_csv
# 3  historical_csv
# 4  historical_csv
# Value columns to use (12): ['symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'prev_close', 'change', 'source']
# FILE: S&P500.csv
# Total rows: 24690
# Columns (13): ['date', 'symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'prev_close', 'change', 'source']
# Null values (%):
# date                0.0
# symbol              0.0
# asset_class         0.0
# unit                0.0
# open                0.0
# high                0.0
# low                 0.0
# close               0.0
# volume              0.0
# change_percent      0.0
# prev_close        100.0
# change            100.0
# source              0.0
# dtype: float64
#          date  symbol asset_class unit       open       high        low  \
# 0  1927-12-30  S&P500       index  USD  17.660000  17.660000  17.660000
# 1  1928-01-03  S&P500       index  USD  17.760000  17.760000  17.760000
# 2  1928-01-04  S&P500       index  USD  17.719999  17.719999  17.719999
# 3  1928-01-05  S&P500       index  USD  17.549999  17.549999  17.549999
# 4  1928-01-06  S&P500       index  USD  17.660000  17.660000  17.660000
#
#        close  volume  change_percent  prev_close  change          source
# 0  17.660000       0        0.000000         NaN     NaN  historical_csv
# 1  17.760000       0        0.566254         NaN     NaN  historical_csv
# 2  17.719999       0       -0.225230         NaN     NaN  historical_csv
# 3  17.549999       0       -0.959368         NaN     NaN  historical_csv
# 4  17.660000       0        0.626784         NaN     NaN  historical_csv
# Value columns to use (12): ['symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'prev_close', 'change', 'source']
# FILE: UPCOM.csv
# Total rows: 4177
# Columns (12): ['date', 'symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'change', 'source']
# Null values (%):
# date                0.0
# symbol              0.0
# asset_class         0.0
# unit                0.0
# open                0.0
# high                0.0
# low                 0.0
# close               0.0
# volume              0.0
# change_percent      0.0
# change            100.0
# source              0.0
# dtype: float64
#          date symbol    asset_class   unit   open   high    low  close  \
# 0  2009-06-25  UPCOM  vietnam_index  point  93.71  93.71  93.71  93.71
# 1  2009-06-26  UPCOM  vietnam_index  point  87.89  87.89  87.89  87.89
# 2  2009-06-29  UPCOM  vietnam_index  point  81.83  81.83  81.83  81.83
# 3  2009-06-30  UPCOM  vietnam_index  point  77.67  77.67  77.67  77.67
# 4  2009-07-01  UPCOM  vietnam_index  point  72.47  72.47  72.47  72.47
#
#    volume  change_percent  change   source
# 0   380.0        0.000000     NaN  scraped
# 1   330.0       -6.210650     NaN  scraped
# 2   380.0       -6.894982     NaN  scraped
# 3    60.0       -5.083710     NaN  scraped
# 4   370.0       -6.694992     NaN  scraped
# Value columns to use (11): ['symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'change', 'source']
# FILE: USDVND.csv
# Total rows: 8264
# Columns (13): ['date', 'symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'prev_close', 'change', 'source']
# Null values (%):
# date                0.0
# symbol              0.0
# asset_class         0.0
# unit                0.0
# open                0.0
# high                0.0
# low                 0.0
# close               0.0
# volume              0.0
# change_percent      0.0
# prev_close        100.0
# change            100.0
# source              0.0
# dtype: float64
#          date  symbol asset_class unit     open     high      low    close  \
# 0  1994-08-05  USDVND    currency  VND  10981.0  10981.0  10981.0  10981.0
# 1  1994-08-08  USDVND    currency  VND  10981.0  10981.0  10981.0  10981.0
# 2  1994-08-09  USDVND    currency  VND  10981.0  10981.0  10981.0  10981.0
# 3  1994-08-10  USDVND    currency  VND  10981.0  10981.0  10981.0  10981.0
# 4  1994-08-11  USDVND    currency  VND  10981.0  10981.0  10981.0  10981.0
#
#    volume  change_percent  prev_close  change          source
# 0     0.0             0.0         NaN     NaN  historical_csv
# 1     0.0             0.0         NaN     NaN  historical_csv
# 2     0.0             0.0         NaN     NaN  historical_csv
# 3     0.0             0.0         NaN     NaN  historical_csv
# 4     0.0             0.0         NaN     NaN  historical_csv
# Value columns to use (12): ['symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'prev_close', 'change', 'source']
# FILE: VN30.csv
# Total rows: 4290
# Columns (12): ['date', 'symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'change', 'source']
# Null values (%):
# date                0.0
# symbol              0.0
# asset_class         0.0
# unit                0.0
# open                0.0
# high                0.0
# low                 0.0
# close               0.0
# volume              0.0
# change_percent      0.0
# change            100.0
# source              0.0
# dtype: float64
#          date symbol    asset_class   unit    open    high     low   close  \
# 0  2009-01-05   VN30  vietnam_index  point  311.23  311.23  311.23  311.23
# 1  2009-01-06   VN30  vietnam_index  point  314.21  314.21  314.21  314.21
# 2  2009-01-07   VN30  vietnam_index  point  320.53  320.53  320.53  320.53
# 3  2009-01-08   VN30  vietnam_index  point  314.14  314.14  314.14  314.14
# 4  2009-01-09   VN30  vietnam_index  point  312.90  312.90  312.90  312.90
#
#    volume  change_percent  change   source
# 0     0.0        0.000000     NaN  scraped
# 1     0.0        0.957491     NaN  scraped
# 2     0.0        2.011394     NaN  scraped
# 3     0.0       -1.993573     NaN  scraped
# 4     0.0       -0.394728     NaN  scraped
# Value columns to use (11): ['symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'change', 'source']
# FILE: VNINDEX.csv
# Total rows: 6240
# Columns (12): ['date', 'symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'change', 'source']
# Null values (%):
# date                0.0
# symbol              0.0
# asset_class         0.0
# unit                0.0
# open                0.0
# high                0.0
# low                 0.0
# close               0.0
# volume              0.0
# change_percent      0.0
# change            100.0
# source              0.0
# dtype: float64
#          date   symbol    asset_class   unit    open    high     low   close  \
# 0  2000-07-31  VNINDEX  vietnam_index  point  101.55  101.55  101.55  101.55
# 1  2000-08-02  VNINDEX  vietnam_index  point  103.38  103.38  103.38  103.38
# 2  2000-08-04  VNINDEX  vietnam_index  point  105.20  105.20  105.20  105.20
# 3  2000-08-07  VNINDEX  vietnam_index  point  106.92  106.92  106.92  106.92
# 4  2000-08-09  VNINDEX  vietnam_index  point  108.64  108.64  108.64  108.64
#
#    volume  change_percent  change   source
# 0    10.0        0.000000     NaN  scraped
# 1     0.0        1.802068     NaN  scraped
# 2     0.0        1.760495     NaN  scraped
# 3    10.0        1.634981     NaN  scraped
# 4    20.0        1.608679     NaN  scraped
# Value columns to use (11): ['symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'change', 'source']
# FILE: brent.csv
# Total rows: 4658
# Columns (13): ['date', 'symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'prev_close', 'change', 'source']
# Null values (%):
# date                0.0
# symbol              0.0
# asset_class         0.0
# unit                0.0
# open                0.0
# high                0.0
# low                 0.0
# close               0.0
# volume              0.0
# change_percent      0.0
# prev_close        100.0
# change            100.0
# source              0.0
# dtype: float64
#          date symbol asset_class        unit       open       high        low  \
# 0  2007-07-30  brent   commodity  USD/barrel  75.849998  76.529999  75.440002
# 1  2007-07-31  brent   commodity  USD/barrel  75.699997  77.169998  75.669998
# 2  2007-08-01  brent   commodity  USD/barrel  77.000000  77.059998  74.860001
# 3  2007-08-02  brent   commodity  USD/barrel  75.220001  76.209999  74.269997
# 4  2007-08-03  brent   commodity  USD/barrel  75.389999  76.000000  74.529999
#
#        close  volume  change_percent  prev_close  change          source
# 0  75.739998    2575        0.000000         NaN     NaN  historical_csv
# 1  77.050003    3513        1.729608         NaN     NaN  historical_csv
# 2  75.349998    3930       -2.206365         NaN     NaN  historical_csv
# 3  75.760002    6180        0.544132         NaN     NaN  historical_csv
# 4  74.750000    4387       -1.333160         NaN     NaN  historical_csv
# Value columns to use (12): ['symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'prev_close', 'change', 'source']
# FILE: broad_money.csv
# Total rows: 376
# Columns (6): ['date', 'indicator', 'value', 'unit', 'source', 'processing_date']
# Null values (%):
# date               0.0
# indicator          0.0
# value              0.0
# unit               0.0
# source             0.0
# processing_date    0.0
# dtype: float64
#          date    indicator  value     unit         source processing_date
# 0  1995-01-01  broad_money  3.567  Percent  CEIC Database      2026-05-20
# 1  1995-02-01  broad_money  3.303  Percent  CEIC Database      2026-05-20
# 2  1995-03-01  broad_money  3.495  Percent  CEIC Database      2026-05-20
# 3  1995-04-01  broad_money  3.434  Percent  CEIC Database      2026-05-20
# 4  1995-05-01  broad_money  3.247  Percent  CEIC Database      2026-05-20
# Value columns to use (5): ['indicator', 'value', 'unit', 'source', 'processing_date']
# FILE: core_inflation_rate.csv
# Total rows: 131
# Columns (5): ['date', 'indicator', 'value', 'unit', 'processing_date']
# Null values (%):
# date               0.0
# indicator          0.0
# value              0.0
# unit               0.0
# processing_date    0.0
# dtype: float64
#          date            indicator  value unit processing_date
# 0  2015-04-01  core_inflation_rate   2.20    %      2026-04-18
# 1  2015-05-01  core_inflation_rate   2.10    %      2026-04-18
# 2  2015-06-01  core_inflation_rate   2.01    %      2026-04-18
# 3  2015-07-01  core_inflation_rate   2.04    %      2026-04-18
# 4  2015-08-01  core_inflation_rate   1.98    %      2026-04-18
# Value columns to use (4): ['indicator', 'value', 'unit', 'processing_date']
# FILE: cpi_base_year.csv
# Total rows: 30
# Columns (8): ['date', 'indicator', 'prev_year_base', 'base_2000', 'base_2005', 'base_2010', 'unit', 'processing_date']
# Null values (%):
# date               0.0
# indicator          0.0
# prev_year_base     0.0
# base_2000          0.0
# base_2005          0.0
# base_2010          0.0
# unit               0.0
# processing_date    0.0
# dtype: float64
#          date      indicator  prev_year_base  base_2000  base_2005  base_2010  \
# 0  1995-01-01  cpi_base_year       99.356595      100.0      100.0      100.0
# 1  1996-01-01  cpi_base_year       99.356595      100.0      100.0      100.0
# 2  1997-01-01  cpi_base_year       99.925280      100.0      100.0      100.0
# 3  1998-01-01  cpi_base_year      100.432037      100.0      100.0      100.0
# 4  1999-01-01  cpi_base_year       99.280278      100.0      100.0      100.0
#
#      unit processing_date
# 0  points      2026-04-18
# 1  points      2026-04-18
# 2  points      2026-04-18
# 3  points      2026-04-18
# 4  points      2026-04-18
# Value columns to use (7): ['indicator', 'prev_year_base', 'base_2000', 'base_2005', 'base_2010', 'unit', 'processing_date']
# FILE: cpi_mom.csv
# Total rows: 360
# Columns (7): ['date', 'indicator', 'cpi', 'inflation', 'avg_year', 'unit', 'processing_date']
# Null values (%):
# date               0.0
# indicator          0.0
# cpi                0.0
# inflation          0.0
# avg_year           0.0
# unit               0.0
# processing_date    0.0
# dtype: float64
#          date indicator    cpi  inflation  avg_year    unit processing_date
# 0  1995-01-01   cpi_mom  103.8  -0.385356   101.025  points      2026-04-18
# 1  1995-02-01   cpi_mom  103.4  -0.385356   101.025  points      2026-04-18
# 2  1995-03-01   cpi_mom  100.2  -3.094778   101.025  points      2026-04-18
# 3  1995-04-01   cpi_mom  101.0   0.798403   101.025  points      2026-04-18
# 4  1995-05-01   cpi_mom  101.8   0.792079   101.025  points      2026-04-18
# Value columns to use (6): ['indicator', 'cpi', 'inflation', 'avg_year', 'unit', 'processing_date']
# FILE: cpi_mom_processed.csv
# Total rows: 360
# Columns (7): ['date', 'indicator', 'cpi', 'inflation', 'avg_year', 'unit', 'processing_date']
# Null values (%):
# date               0.0
# indicator          0.0
# cpi                0.0
# inflation          0.0
# avg_year           0.0
# unit               0.0
# processing_date    0.0
# dtype: float64
#          date indicator    cpi  inflation  avg_year    unit processing_date
# 0  1995-01-01   cpi_mom  103.8        3.8   101.025  points      2026-06-02
# 1  1995-02-01   cpi_mom  103.4        3.4   101.025  points      2026-06-02
# 2  1995-03-01   cpi_mom  100.2        0.2   101.025  points      2026-06-02
# 3  1995-04-01   cpi_mom  101.0        1.0   101.025  points      2026-06-02
# 4  1995-05-01   cpi_mom  101.8        1.8   101.025  points      2026-06-02
# Value columns to use (6): ['indicator', 'cpi', 'inflation', 'avg_year', 'unit', 'processing_date']
# FILE: gasoline.csv
# Total rows: 1107
# Columns (8): ['date', 'type', 'product', 'price', 'change', 'unit', 'source', 'processing_date']
# Null values (%):
# date               0.00
# type               0.00
# product            0.00
# price              0.00
# change             0.36
# unit               0.00
# source             0.00
# processing_date    0.00
# dtype: float64
#          date      type    product    price  change       unit source  \
# 0  01-01-2019  Gasoline     RON 95  17600.0  -540.0  VND/liter  PVOIL
# 1  01-01-2019  Gasoline  E5 RON 92  16270.0  -510.0  VND/liter  PVOIL
# 2  01-01-2019    Diesel         DO  14900.0 -1100.0  VND/liter  PVOIL
# 3  01-01-2019  Kerosene         KO  14180.0  -820.0  VND/liter  PVOIL
# 4  01-01-2023  Gasoline     RON 95  21800.0  1100.0  VND/liter  PVOIL
#
#   processing_date
# 0      2026-04-18
# 1      2026-04-18
# 2      2026-04-18
# 3      2026-04-18
# 4      2026-04-18
# Value columns to use (7): ['type', 'product', 'price', 'change', 'unit', 'source', 'processing_date']
# FILE: gasoline_world.csv
# Total rows: 6395
# Columns (13): ['date', 'symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'prev_close', 'change', 'source']
# Null values (%):
# date                0.0
# symbol              0.0
# asset_class         0.0
# unit                0.0
# open                0.0
# high                0.0
# low                 0.0
# close               0.0
# volume              0.0
# change_percent      0.0
# prev_close        100.0
# change            100.0
# source              0.0
# dtype: float64
#          date          symbol asset_class        unit    open    high    low  \
# 0  01/11/2000  gasoline_world   commodity  USD/gallon  0.8890  0.8970  0.882
# 1  02/11/2000  gasoline_world   commodity  USD/gallon  0.8750  0.8876  0.863
# 2  03/11/2000  gasoline_world   commodity  USD/gallon  0.8675  0.8750  0.860
# 3  06/11/2000  gasoline_world   commodity  USD/gallon  0.8600  0.8850  0.856
# 4  07/11/2000  gasoline_world   commodity  USD/gallon  0.8930  0.9000  0.886
#
#     close  volume  change_percent  prev_close  change          source
# 0  0.8840   16223        0.000000         NaN     NaN  historical_csv
# 1  0.8688   17216       -1.719459         NaN     NaN  historical_csv
# 2  0.8695   10170        0.080571         NaN     NaN  historical_csv
# 3  0.8825   16184        1.495113         NaN     NaN  historical_csv
# 4  0.8910   15717        0.963171         NaN     NaN  historical_csv
# Value columns to use (12): ['symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'prev_close', 'change', 'source']
# FILE: gdp.csv
# Total rows: 89
# Columns (6): ['date', 'indicator', 'value', 'unit', 'source', 'processing_date']
# Null values (%):
# date               0.0
# indicator          0.0
# value              0.0
# unit               0.0
# source             0.0
# processing_date    0.0
# dtype: float64
#          date  indicator     value     unit       source processing_date
# 0  2003-07-01  gdp_total  434478.0  Tỷ đồng  GSO Vietnam      2026-06-02
# 1  2003-10-01  gdp_total  536099.0  Tỷ đồng  GSO Vietnam      2026-06-02
# 2  2004-01-01  gdp_total  192958.0  Tỷ đồng  GSO Vietnam      2026-06-02
# 3  2004-04-01  gdp_total  435459.0  Tỷ đồng  GSO Vietnam      2026-06-02
# 4  2004-07-01  gdp_total  492406.0  Tỷ đồng  GSO Vietnam      2026-06-02
# Value columns to use (5): ['indicator', 'value', 'unit', 'source', 'processing_date']
# FILE: gold.csv
# Total rows: 6431
# Columns (13): ['date', 'symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'prev_close', 'change', 'source']
# Null values (%):
# date                0.0
# symbol              0.0
# asset_class         0.0
# unit                0.0
# open                0.0
# high                0.0
# low                 0.0
# close               0.0
# volume              0.0
# change_percent      0.0
# prev_close        100.0
# change            100.0
# source              0.0
# dtype: float64
#          date symbol asset_class       unit        open        high  \
# 0  2000-08-30   gold   commodity  USD/ounce  273.899994  273.899994
# 1  2000-08-31   gold   commodity  USD/ounce  274.799988  278.299988
# 2  2000-09-01   gold   commodity  USD/ounce  277.000000  277.000000
# 3  2000-09-05   gold   commodity  USD/ounce  275.799988  275.799988
# 4  2000-09-06   gold   commodity  USD/ounce  274.200012  274.200012
#
#           low       close  volume  change_percent  prev_close  change  \
# 0  273.899994  273.899994       0        0.000000         NaN     NaN
# 1  274.799988  278.299988       0        1.606424         NaN     NaN
# 2  277.000000  277.000000       0       -0.467117         NaN     NaN
# 3  275.799988  275.799988       2       -0.433217         NaN     NaN
# 4  274.200012  274.200012       0       -0.580122         NaN     NaN
#
#            source
# 0  historical_csv
# 1  historical_csv
# 2  historical_csv
# 3  historical_csv
# 4  historical_csv
# Value columns to use (12): ['symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'prev_close', 'change', 'source']
# FILE: interest_rate.csv
# Total rows: 765
# Columns (7): ['date', 'term', 'symbol', 'interest_rate', 'volume', 'source', 'processing_date']
# Null values (%):
# date               0.0
# term               0.0
# symbol             0.0
# interest_rate      0.0
# volume             0.0
# source             0.0
# processing_date    0.0
# dtype: float64
#          date      term symbol  interest_rate volume                 source  \
# 0  2014-04-01   1 Month     1M           2.95    571  Viet Nam Central Bank
# 1  2014-04-01    1 Week     1W           2.48   4248  Viet Nam Central Bank
# 2  2014-04-01   2 Weeks     2W           2.69   1617  Viet Nam Central Bank
# 3  2014-04-01  3 Months     3M           3.85     20  Viet Nam Central Bank
# 4  2014-04-01  6 Months     6M           5.81    238  Viet Nam Central Bank
#
#   processing_date
# 0      2026-04-18
# 1      2026-04-18
# 2      2026-04-18
# 3      2026-04-18
# 4      2026-04-18
# Value columns to use (6): ['term', 'symbol', 'interest_rate', 'volume', 'source', 'processing_date']
# FILE: m2.csv
# Total rows: 195
# Columns (6): ['date', 'indicator', 'value', 'unit', 'source', 'processing_date']
# Null values (%):
# date               0.0
# indicator          0.0
# value              0.0
# unit               0.0
# source             0.0
# processing_date    0.0
# dtype: float64
#          date indicator    value         unit                    source  \
# 0  2009-03-01        m2  1748226  Billion VND  Funan Research Institute
# 1  2009-06-01        m2  1907523  Billion VND  Funan Research Institute
# 2  2009-09-01        m2  1986084  Billion VND  Funan Research Institute
# 3  2009-12-01        m2  2092447  Billion VND  Funan Research Institute
# 4  2010-01-01        m2  1951164  Billion VND  Funan Research Institute
#
#   processing_date
# 0      2026-04-18
# 1      2026-04-18
# 2      2026-04-18
# 3      2026-04-18
# 4      2026-04-18
# Value columns to use (5): ['indicator', 'value', 'unit', 'source', 'processing_date']
# FILE: natural_gas.csv
# Total rows: 6437
# Columns (13): ['date', 'symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'prev_close', 'change', 'source']
# Null values (%):
# date                0.0
# symbol              0.0
# asset_class         0.0
# unit                0.0
# open                0.0
# high                0.0
# low                 0.0
# close               0.0
# volume              0.0
# change_percent      0.0
# prev_close        100.0
# change            100.0
# source              0.0
# dtype: float64
#          date       symbol asset_class       unit  open   high   low  close  \
# 0  2000-08-30  natural_gas   commodity  USD/MMBtu  4.65  4.815  4.63  4.805
# 1  2000-08-31  natural_gas   commodity  USD/MMBtu  4.82  4.870  4.74  4.780
# 2  2000-09-01  natural_gas   commodity  USD/MMBtu  4.75  4.860  4.75  4.835
# 3  2000-09-05  natural_gas   commodity  USD/MMBtu  4.85  4.975  4.84  4.960
# 4  2000-09-06  natural_gas   commodity  USD/MMBtu  4.99  5.110  4.96  5.065
#
#    volume  change_percent  prev_close  change          source
# 0   34954        0.000000         NaN     NaN  historical_csv
# 1   25787       -0.520283         NaN     NaN  historical_csv
# 2     113        1.150624         NaN     NaN  historical_csv
# 3   26096        2.585315         NaN     NaN  historical_csv
# 4   32764        2.116936         NaN     NaN  historical_csv
# Value columns to use (12): ['symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'prev_close', 'change', 'source']
# FILE: policy_rate.csv
# Total rows: 376
# Columns (6): ['date', 'indicator', 'value', 'unit', 'source', 'processing_date']
# Null values (%):
# date               0.0
# indicator          0.0
# value              0.0
# unit               0.0
# source             0.0
# processing_date    0.0
# dtype: float64
#          date    indicator  value               unit         source  \
# 0  1995-01-01  policy_rate   10.8  Percent per annum  CEIC Database
# 1  1995-02-01  policy_rate   10.8  Percent per annum  CEIC Database
# 2  1995-03-01  policy_rate   10.8  Percent per annum  CEIC Database
# 3  1995-04-01  policy_rate   10.8  Percent per annum  CEIC Database
# 4  1995-05-01  policy_rate   10.8  Percent per annum  CEIC Database
#
#   processing_date
# 0      2026-05-20
# 1      2026-05-20
# 2      2026-05-20
# 3      2026-05-20
# 4      2026-05-20
# Value columns to use (5): ['indicator', 'value', 'unit', 'source', 'processing_date']
# FILE: ppi_qoq.csv
# Total rows: 40
# Columns (5): ['date', 'indicator', 'value', 'unit', 'processing_date']
# Null values (%):
# date               0.0
# indicator          0.0
# value              0.0
# unit               0.0
# processing_date    0.0
# dtype: float64
#          date indicator  value unit processing_date
# 0  2016-01-01   ppi_qoq  -0.73    %      2026-04-18
# 1  2016-04-01   ppi_qoq   0.07    %      2026-04-18
# 2  2016-07-01   ppi_qoq   0.65    %      2026-04-18
# 3  2016-10-01   ppi_qoq   0.38    %      2026-04-18
# 4  2017-01-01   ppi_qoq   0.34    %      2026-04-18
# Value columns to use (4): ['indicator', 'value', 'unit', 'processing_date']
# FILE: silver.csv
# Total rows: 6433
# Columns (13): ['date', 'symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'prev_close', 'change', 'source']
# Null values (%):
# date                0.0
# symbol              0.0
# asset_class         0.0
# unit                0.0
# open                0.0
# high                0.0
# low                 0.0
# close               0.0
# volume              0.0
# change_percent      0.0
# prev_close        100.0
# change            100.0
# source              0.0
# dtype: float64
#          date  symbol asset_class       unit   open   high    low  close  \
# 0  2000-08-30  silver   commodity  USD/ounce  4.950  4.950  4.895  4.930
# 1  2000-08-31  silver   commodity  USD/ounce  4.920  5.045  4.920  5.003
# 2  2000-09-01  silver   commodity  USD/ounce  5.035  5.035  4.985  5.004
# 3  2000-09-05  silver   commodity  USD/ounce  4.990  5.005  4.975  4.998
# 4  2000-09-06  silver   commodity  USD/ounce  5.000  5.000  4.980  4.983
#
#    volume  change_percent  prev_close  change          source
# 0    2319        0.000000         NaN     NaN  historical_csv
# 1    1612        1.480729         NaN     NaN  historical_csv
# 2    1375        0.019996         NaN     NaN  historical_csv
# 3     856       -0.119905         NaN     NaN  historical_csv
# 4     232       -0.300127         NaN     NaN  historical_csv
# Value columns to use (12): ['symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'prev_close', 'change', 'source']
# FILE: wti.csv
# Total rows: 9260
# Columns (13): ['date', 'symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'prev_close', 'change', 'source']
# Null values (%):
# date                0.0
# symbol              0.0
# asset_class         0.0
# unit                0.0
# open                0.0
# high                0.0
# low                 0.0
# close               0.0
# volume              0.0
# change_percent      0.0
# prev_close        100.0
# change            100.0
# source              0.0
# dtype: float64
#          date symbol asset_class        unit   open   high    low  close  \
# 0  1990-01-02    wti   commodity  USD/barrel  21.81  22.92  21.79  22.89
# 1  1990-01-03    wti   commodity  USD/barrel  23.19  23.80  23.00  23.68
# 2  1990-01-04    wti   commodity  USD/barrel  23.90  23.92  22.83  23.41
# 3  1990-01-05    wti   commodity  USD/barrel  23.41  23.70  23.03  23.08
# 4  1990-01-08    wti   commodity  USD/barrel  22.54  22.60  21.55  21.62
#
#     volume  change_percent  prev_close  change          source
# 0  45180.0        0.000000         NaN     NaN  historical_csv
# 1  50060.0        3.451289         NaN     NaN  historical_csv
# 2  53070.0       -1.140203         NaN     NaN  historical_csv
# 3  39720.0       -1.409654         NaN     NaN  historical_csv
# 4  50050.0       -6.325823         NaN     NaN  historical_csv
# Value columns to use (12): ['symbol', 'asset_class', 'unit', 'open', 'high', 'low', 'close', 'volume', 'change_percent', 'prev_close', 'change', 'source']

# %%
loaded_data = {}
file_details = []
failed = []
null_analysis = []

for filename, config in data_config.items():
    try:
        filepath = os.path.join(data_raw_dir, filename)
        
        if not os.path.exists(filepath):
            print(f"{filename:25} | NOT FOUND")
            continue

        df = pd.read_csv(filepath)
        # Lấy 3M và RON 95 
        if filename == 'interest_rate.csv' and 'term' in df.columns:
            term_to_use = config.get('filter_term', '3M')
            df = df[df['term'] == term_to_use].copy()
        
        # if filename == 'gasoline.csv' and 'product' in df.columns:
        #     product_to_use = config.get('filter_product', 'RON 95')
        #     df = df[df['product'] == product_to_use].copy()
        
        file_size = os.path.getsize(filepath) / 1024
        date_col = config['date_col']

        if date_col in df.columns:
            df[date_col] = pd.to_datetime(df[date_col], errors='coerce')

            value_cols = [col for col in config['value_cols'] if col in df.columns]
            
            if value_cols:
                subset = df[[date_col] + value_cols].copy()
                subset = subset.dropna(subset=[date_col] + value_cols)
                # chỉ xóa các cột có 100% null, còn lại giữ lại để phân tích
                for col in subset.columns:
                    if col != date_col:
                        null_count = subset[col].isnull().sum()
                        null_pct = (null_count / len(subset) * 100)
                        if null_pct > 0:
                            null_analysis.append({
                                'File': filename,
                                'Column': col,
                                'Null_Count': null_count,
                                'Null_Percent': f"{null_pct:.2f}%"
                            })
                subset = subset.dropna(axis=1, how='all')
                
                subset = subset.rename(columns={date_col: 'date'})
                for col in subset.columns:
                    if col != 'date':
                        if len(value_cols) == 1:
                            subset = subset.rename(columns={col: filename.replace('.csv', '')})
                        else:
                            subset = subset.rename(columns={col: f"{filename.replace('.csv', '')}_{col}"})
                
                loaded_data[filename] = subset

                file_info = {
                    'Filename': filename,
                    'Category': config['category'],
                    'Total_Rows': len(df),
                    'Data_Rows': len(subset),
                    'Date_Start': subset['date'].min().date(),
                    'Date_End': subset['date'].max().date(),
                    'Columns': len(subset.columns),
                }
                file_details.append(file_info)
                
                print(f"{filename:25} | {len(subset):6,} rows | {config['category']:15}")
    
    except Exception as e:
        failed.append((filename, str(e)))
# Out:
# cpi_mom_processed.csv     |    360 rows | Economic
# core_inflation_rate.csv   |    131 rows | Economic
# interest_rate.csv         |    109 rows | Economic
# ppi_qoq.csv               |     40 rows | Economic
# m2.csv                    |    195 rows | Economic
# broad_money.csv           |    376 rows | Economic
# policy_rate.csv           |    376 rows | Economic
# gdp.csv                   |     89 rows | Economic
# brent.csv                 |  4,658 rows | Commodity
# wti.csv                   |  9,260 rows | Commodity
# gasoline_world.csv        |  2,534 rows | Commodity
# natural_gas.csv           |  6,437 rows | Commodity
# gold.csv                  |  6,431 rows | Commodity
# silver.csv                |  6,433 rows | Commodity
# VNINDEX.csv               |  6,240 rows | VN_Stock
# VN30.csv                  |  4,290 rows | VN_Stock
# HNX.csv                   |  5,071 rows | VN_Stock
# UPCOM.csv                 |  4,177 rows | VN_Stock
# NASDAQ.csv                | 13,916 rows | Global_Stock
# S&P500.csv                | 24,690 rows | Global_Stock
# DAX.csv                   |  9,683 rows | Global_Stock
# DOWJONES.csv              |  8,634 rows | Global_Stock
# NIKKEI225.csv             | 15,067 rows | Global_Stock
# HANGSENG.csv              |  9,696 rows | Global_Stock
# USDVND.csv                |  8,264 rows | Currency

# %% [markdown]
# ### Chi Tiết Từng File

# %%
if null_analysis:
    null_df = pd.DataFrame(null_analysis)
    for file in null_df['File'].unique():
        file_nulls = null_df[null_df['File'] == file]
        print(f"{file}:")
        for _, row in file_nulls.iterrows():
            print(f"{row['Column']:30} | {row['Null_Count']:5} nulls ({row['Null_Percent']})")
else:
    print("No null value")
# Out:
# No null value

# %%
file_details_df = pd.DataFrame(file_details)

for category in file_details_df['Category'].unique():
    category_files = file_details_df[file_details_df['Category'] == category]
    total_rows = category_files['Data_Rows'].astype(int).sum()
    print(f"  • {category:20} | {len(category_files):2} files | {total_rows:,} total rows")

for idx, row in file_details_df.iterrows():
    print(f"""
  File {idx+1}: {row['Filename']}
    - Category: {row['Category']}
    - Rows: {row['Total_Rows']} (sau lọc: {row['Data_Rows']})
    - Date Range: {row['Date_Start']} to {row['Date_End']}
    - Columns: {row['Columns']}
  """)
# Out:
#   • Economic             |  8 files | 1,676 total rows
#   • Commodity            |  6 files | 35,753 total rows
#   • VN_Stock             |  4 files | 19,778 total rows
#   • Global_Stock         |  6 files | 81,686 total rows
#   • Currency             |  1 files | 8,264 total rows
#
#   File 1: cpi_mom_processed.csv
#     - Category: Economic
#     - Rows: 360 (sau lọc: 360)
#     - Date Range: 1995-01-01 to 2024-12-01
#     - Columns: 3
#
#
#   File 2: core_inflation_rate.csv
#     - Category: Economic
#     - Rows: 131 (sau lọc: 131)
#     - Date Range: 2015-04-01 to 2026-02-01
#     - Columns: 2
#
#
#   File 3: interest_rate.csv
#     - Category: Economic
#     - Rows: 109 (sau lọc: 109)
#     - Date Range: 2014-04-01 to 2026-04-14
#     - Columns: 2
#
#
#   File 4: ppi_qoq.csv
#     - Category: Economic
#     - Rows: 40 (sau lọc: 40)
#     - Date Range: 2016-01-01 to 2025-10-01
#     - Columns: 2
#
#
#   File 5: m2.csv
#     - Category: Economic
#     - Rows: 195 (sau lọc: 195)
#     - Date Range: 2009-03-01 to 2026-01-01
#     - Columns: 2
#
#
#   File 6: broad_money.csv
#     - Category: Economic
#     - Rows: 376 (sau lọc: 376)
#     - Date Range: 1995-01-01 to 2026-04-01
#     - Columns: 2
#
#
#   File 7: policy_rate.csv
#     - Category: Economic
#     - Rows: 376 (sau lọc: 376)
#     - Date Range: 1995-01-01 to 2026-04-01
#     - Columns: 2
#
#
#   File 8: gdp.csv
#     - Category: Economic
#     - Rows: 89 (sau lọc: 89)
#     - Date Range: 2003-07-01 to 2026-01-01
#     - Columns: 2
#
#
#   File 9: brent.csv
#     - Category: Commodity
#     - Rows: 4658 (sau lọc: 4658)
#     - Date Range: 2007-07-30 to 2026-04-17
#     - Columns: 2
#
#
#   File 10: wti.csv
#     - Category: Commodity
#     - Rows: 9260 (sau lọc: 9260)
#     - Date Range: 1990-01-02 to 2026-04-17
#     - Columns: 2
#
#
#   File 11: gasoline_world.csv
#     - Category: Commodity
#     - Rows: 6395 (sau lọc: 2534)
#     - Date Range: 2000-01-11 to 2026-12-03
#     - Columns: 2
#
#
#   File 12: natural_gas.csv
#     - Category: Commodity
#     - Rows: 6437 (sau lọc: 6437)
#     - Date Range: 2000-08-30 to 2026-04-17
#     - Columns: 2
#
#
#   File 13: gold.csv
#     - Category: Commodity
#     - Rows: 6431 (sau lọc: 6431)
#     - Date Range: 2000-08-30 to 2026-04-17
#     - Columns: 2
#
#
#   File 14: silver.csv
#     - Category: Commodity
#     - Rows: 6433 (sau lọc: 6433)
#     - Date Range: 2000-08-30 to 2026-04-17
#     - Columns: 2
#
#
#   File 15: VNINDEX.csv
#     - Category: VN_Stock
#     - Rows: 6240 (sau lọc: 6240)
#     - Date Range: 2000-07-31 to 2026-03-18
#     - Columns: 2
#
#
#   File 16: VN30.csv
#     - Category: VN_Stock
#     - Rows: 4290 (sau lọc: 4290)
#     - Date Range: 2009-01-05 to 2026-03-18
#     - Columns: 2
#
#
#   File 17: HNX.csv
#     - Category: VN_Stock
#     - Rows: 5071 (sau lọc: 5071)
#     - Date Range: 2005-07-18 to 2026-03-18
#     - Columns: 2
#
#
#   File 18: UPCOM.csv
#     - Category: VN_Stock
#     - Rows: 4177 (sau lọc: 4177)
#     - Date Range: 2009-06-25 to 2026-03-18
#     - Columns: 2
#
#
#   File 19: NASDAQ.csv
#     - Category: Global_Stock
#     - Rows: 13916 (sau lọc: 13916)
#     - Date Range: 1971-02-05 to 2026-04-17
#     - Columns: 2
#
#
#   File 20: S&P500.csv
#     - Category: Global_Stock
#     - Rows: 24690 (sau lọc: 24690)
#     - Date Range: 1927-12-30 to 2026-04-17
#     - Columns: 2
#
#
#   File 21: DAX.csv
#     - Category: Global_Stock
#     - Rows: 9683 (sau lọc: 9683)
#     - Date Range: 1987-12-30 to 2026-04-17
#     - Columns: 2
#
#
#   File 22: DOWJONES.csv
#     - Category: Global_Stock
#     - Rows: 8634 (sau lọc: 8634)
#     - Date Range: 1992-01-02 to 2026-04-17
#     - Columns: 2
#
#
#   File 23: NIKKEI225.csv
#     - Category: Global_Stock
#     - Rows: 15067 (sau lọc: 15067)
#     - Date Range: 1965-01-05 to 2026-04-17
#     - Columns: 2
#
#
#   File 24: HANGSENG.csv
#     - Category: Global_Stock
#     - Rows: 9696 (sau lọc: 9696)
#     - Date Range: 1986-12-31 to 2026-04-17
#     - Columns: 2
#
#
#   File 25: USDVND.csv
#     - Category: Currency
#     - Rows: 8264 (sau lọc: 8264)
#     - Date Range: 1994-08-05 to 2026-04-17
#     - Columns: 2

# %% [markdown]
# ## BƯỚC 3: Gộp Tần Suất Thành Hàng Tháng

# %%
min_date = pd.Timestamp('1995-01-01')
# max_day của cpi_mom 
max_date  = pd.Timestamp('2024-12-01')
time_axis = pd.date_range(start=min_date, end=max_date, freq='MS')
time_index = pd.DataFrame({'date': time_axis})

print(f"  Standard time axis: {time_axis[0].date()} to {time_axis[-1].date()}")
print(f"  Total months: {len(time_axis)}")
# Out:
#   Standard time axis: 1995-01-01 to 2024-12-01
#   Total months: 360

# %%
frequency_analysis = []

for filename, config in data_config.items():
    try:
        filepath = os.path.join(data_raw_dir, filename)
        
        if not os.path.exists(filepath):
            continue

        df = pd.read_csv(filepath)

        if filename == 'interest_rate.csv' and 'term' in df.columns:
            term_to_use = config.get('filter_term', '3M')
            df = df[df['term'] == term_to_use].copy()
        
        if filename == 'gasoline.csv' and 'product' in df.columns:
            product_to_use = config.get('filter_product', 'RON 95')
            df = df[df['product'] == product_to_use].copy()
        
        date_col = config['date_col']
        if date_col in df.columns:
            df[date_col] = pd.to_datetime(df[date_col], errors='coerce')

            df_sorted = df.sort_values(date_col)
            dates = df_sorted[date_col].unique()
            
            if len(dates) > 1:
                date_diffs = pd.Series(dates[1:]) - pd.Series(dates[:-1])
                min_diff = date_diffs.min().days
                max_diff = date_diffs.max().days
                mode_diff = date_diffs.mode()[0].days if len(date_diffs.mode()) > 0 else None

                if mode_diff == 1:
                    freq_type = "DAILY"
                elif mode_diff == 7:
                    freq_type = "WEEKLY"
                elif 28 <= mode_diff <= 31:
                    freq_type = "MONTHLY"
                elif mode_diff == 365 or mode_diff == 366:
                    freq_type = "ANNUAL"
                else:
                    freq_type = f"OTHER ({mode_diff}d)"
                
                rows_per_day = len(df) / ((df[date_col].max() - df[date_col].min()).days + 1)
                
                frequency_analysis.append({
                    'File': filename,
                    'Category': config['category'],
                    'Total_Rows': len(df),
                    'Date_Range': f"{df_sorted[date_col].min().date()} to {df_sorted[date_col].max().date()}",
                    'Frequency': freq_type,
                    'Min_Gap_Days': min_diff,
                    'Max_Gap_Days': max_diff,
                    'Rows_Per_Day': f"{rows_per_day:.2f}",
                    'Needs_Resample': "NO" if freq_type == "MONTHLY" else "YES"
                })
    
    except Exception as e:
        pass

freq_df = pd.DataFrame(frequency_analysis)

for freq in freq_df['Frequency'].unique():
    files_with_freq = freq_df[freq_df['Frequency'] == freq]
    print(f"\n{freq:10} ({len(files_with_freq)} files):")
    for _, row in files_with_freq.iterrows():
        needs = "RESAMPLE" if row['Needs_Resample'] == "YES" else "KEEP AS-IS"
        print(f"  • {row['File']:25} | {row['Total_Rows']:6,} rows | {needs}")


print(f"{'File':<25} {'Category':<18} {'Frequency':<10} {'Total Rows':<12} {'Resample?':<12}")
print("-" * 120)

for _, row in freq_df.iterrows():
    needs = row['Needs_Resample']
    print(f"{row['File']:<25} {row['Category']:<18} {row['Frequency']:<10} {row['Total_Rows']:<12,} {needs:<12}")

resample_count = (freq_df['Needs_Resample'] == "YES").sum()
keep_count = (freq_df['Needs_Resample'] == "NO").sum()

print("\n" + "="*120)
print(f"KHÔNG RESAMPLE (đã monthly): {keep_count} files")
print(f"CẦN RESAMPLE (daily/other): {resample_count} files")
# Out:
# MONTHLY    (5 files):
#   • cpi_mom_processed.csv     |    360 rows | KEEP AS-IS
#   • core_inflation_rate.csv   |    131 rows | KEEP AS-IS
#   • m2.csv                    |    195 rows | KEEP AS-IS
#   • broad_money.csv           |    376 rows | KEEP AS-IS
#   • policy_rate.csv           |    376 rows | KEEP AS-IS
#
# DAILY      (18 files):
#   • interest_rate.csv         |    109 rows | RESAMPLE
#   • brent.csv                 |  4,658 rows | RESAMPLE
#   • wti.csv                   |  9,260 rows | RESAMPLE
#   • gasoline_world.csv        |  6,395 rows | RESAMPLE
#   • natural_gas.csv           |  6,437 rows | RESAMPLE
#   • gold.csv                  |  6,431 rows | RESAMPLE
#   • silver.csv                |  6,433 rows | RESAMPLE
#   • VNINDEX.csv               |  6,240 rows | RESAMPLE
#   • VN30.csv                  |  4,290 rows | RESAMPLE
#   • HNX.csv                   |  5,071 rows | RESAMPLE
#   • UPCOM.csv                 |  4,177 rows | RESAMPLE
#   • NASDAQ.csv                | 13,916 rows | RESAMPLE
#   • S&P500.csv                | 24,690 rows | RESAMPLE
#   • DAX.csv                   |  9,683 rows | RESAMPLE
#   • DOWJONES.csv              |  8,634 rows | RESAMPLE
#   • NIKKEI225.csv             | 15,067 rows | RESAMPLE
#   • HANGSENG.csv              |  9,696 rows | RESAMPLE
#   • USDVND.csv                |  8,264 rows | RESAMPLE
#
# OTHER (92d) (2 files):
#   • ppi_qoq.csv               |     40 rows | RESAMPLE
#   • gdp.csv                   |     89 rows | RESAMPLE
# File                      Category           Frequency  Total Rows   Resample?
# ------------------------------------------------------------------------------------------------------------------------
# cpi_mom_processed.csv     Economic           MONTHLY    360          NO
# core_inflation_rate.csv   Economic           MONTHLY    131          NO
# interest_rate.csv         Economic           DAILY      109          YES
# ppi_qoq.csv               Economic           OTHER (92d) 40           YES
# m2.csv                    Economic           MONTHLY    195          NO
# broad_money.csv           Economic           MONTHLY    376          NO
# policy_rate.csv           Economic           MONTHLY    376          NO
# gdp.csv                   Economic           OTHER (92d) 89           YES
# brent.csv                 Commodity          DAILY      4,658        YES
# wti.csv                   Commodity          DAILY      9,260        YES
# gasoline_world.csv        Commodity          DAILY      6,395        YES
# natural_gas.csv           Commodity          DAILY      6,437        YES
# gold.csv                  Commodity          DAILY      6,431        YES
# silver.csv                Commodity          DAILY      6,433        YES
# VNINDEX.csv               VN_Stock           DAILY      6,240        YES
# VN30.csv                  VN_Stock           DAILY      4,290        YES
# HNX.csv                   VN_Stock           DAILY      5,071        YES
# UPCOM.csv                 VN_Stock           DAILY      4,177        YES
# NASDAQ.csv                Global_Stock       DAILY      13,916       YES
# S&P500.csv                Global_Stock       DAILY      24,690       YES
# DAX.csv                   Global_Stock       DAILY      9,683        YES
# DOWJONES.csv              Global_Stock       DAILY      8,634        YES
# NIKKEI225.csv             Global_Stock       DAILY      15,067       YES
# HANGSENG.csv              Global_Stock       DAILY      9,696        YES
# USDVND.csv                Currency           DAILY      8,264        YES
#
# ========================================================================================================================
# KHÔNG RESAMPLE (đã monthly): 5 files
# CẦN RESAMPLE (daily/other): 20 files

# %%
monthly_data = {}
agg_report = []

files_keep_monthly = {'cpi_mom_processed.csv', 'core_inflation_rate.csv', 'm2.csv','policy_rate.csv','broad_money.csv'}  # Đã monthly - giữ nguyên
files_downsample = set(freq_df[freq_df['Frequency'] == 'DAILY']['File'].values)  

files_quarterly = {'ppi_qoq.csv', 'gdp.csv'}      # Quarterly - 1 value/quarter → repeat cho 3 tháng
files_irregular = {'interest_rate.csv'} # Irregular - dùng ffill

for filename, df in loaded_data.items():
    try:
        df_sorted = df.sort_values('date').copy()

        if filename in files_keep_monthly:
            monthly_data[filename] = df_sorted
            print(f" {filename:25} | KEEP MONTHLY | {len(df_sorted)} rows")
            agg_report.append({
                'Filename': filename,
                'Strategy': 'KEEP_MONTHLY',
                'Original_Rows': len(df),
                'Monthly_Rows': len(df_sorted),
                'Features': len(df_sorted.columns) - 1
            })

        elif filename in files_downsample:
            df_agg = df_sorted.copy()
            df_agg = df_agg.set_index('date')
            value_cols = [col for col in df_agg.columns]
            
            resampled = df_agg[value_cols].resample('MS').agg({
                col: 'last'
                for col in value_cols
            })
            resampled = resampled.reset_index()
            
            monthly_data[filename] = resampled
            compression_ratio = (len(resampled) / len(df)) * 100
            
            print(f"⬇ {filename:25} | DOWNSAMPLE Daily→Monthly | {len(df):6,} → {len(resampled):4,} rows | Compression {compression_ratio:.1f}%")
            agg_report.append({
                'Filename': filename,
                'Strategy': 'DOWNSAMPLE_DAILY',
                'Original_Rows': len(df),
                'Monthly_Rows': len(resampled),
                'Features': len(resampled.columns) - 1
            })

        elif filename in files_quarterly:
            df_agg = df_sorted.copy()
            df_agg = df_agg.set_index('date')
            value_cols = [col for col in df_agg.columns]
  
            resampled = df_agg[value_cols].resample('MS').ffill()
            resampled = resampled.reset_index()
            
            monthly_data[filename] = resampled
            print(f"⬆ {filename:25} | UPSAMPLE Quarterly→Monthly (repeat 3 months) | {len(df):6,} → {len(resampled):6,} rows | Forward Fill")
            agg_report.append({
                'Filename': filename,
                'Strategy': 'UPSAMPLE_QUARTERLY_FFILL',
                'Original_Rows': len(df),
                'Monthly_Rows': len(resampled),
                'Features': len(resampled.columns) - 1
            })

        elif filename in files_irregular:
            df_agg = df_sorted.copy()
            df_agg = df_agg.set_index('date')
            value_cols = [col for col in df_agg.columns]
            
            resampled = df_agg[value_cols].resample('MS').ffill()
            resampled = resampled.reset_index()
            
            monthly_data[filename] = resampled
            print(f"⬆ {filename:25} | UPSAMPLE Irregular→Monthly | {len(df):6,} → {len(resampled):6,} rows | Forward Fill")
            agg_report.append({
                'Filename': filename,
                'Strategy': 'UPSAMPLE_IRREGULAR_FFILL',
                'Original_Rows': len(df),
                'Monthly_Rows': len(resampled),
                'Features': len(resampled.columns) - 1
            })
    
    except Exception as e:
        print(f"✗ {filename:25} | ERROR: {str(e)[:40]}")

print(f"\n Resample thành công: {len(monthly_data)} files")

agg_df = pd.DataFrame(agg_report)
for strategy in agg_df['Strategy'].unique():
    strategy_df = agg_df[agg_df['Strategy'] == strategy]
    total_features = strategy_df['Features'].sum()
    print(f"{strategy:30} | {len(strategy_df):2d} files | Total rows: {strategy_df['Original_Rows'].sum():,} → {strategy_df['Monthly_Rows'].sum():,} | Total features: {total_features:3d}")
# Out:
#  cpi_mom_processed.csv     | KEEP MONTHLY | 360 rows
#  core_inflation_rate.csv   | KEEP MONTHLY | 131 rows
# ⬇ interest_rate.csv         | DOWNSAMPLE Daily→Monthly |    109 →  145 rows | Compression 133.0%
# ⬆ ppi_qoq.csv               | UPSAMPLE Quarterly→Monthly (repeat 3 months) |     40 →    118 rows | Forward Fill
#  m2.csv                    | KEEP MONTHLY | 195 rows
#  broad_money.csv           | KEEP MONTHLY | 376 rows
#  policy_rate.csv           | KEEP MONTHLY | 376 rows
# ⬆ gdp.csv                   | UPSAMPLE Quarterly→Monthly (repeat 3 months) |     89 →    271 rows | Forward Fill
# ⬇ brent.csv                 | DOWNSAMPLE Daily→Monthly |  4,658 →  226 rows | Compression 4.9%
# ⬇ wti.csv                   | DOWNSAMPLE Daily→Monthly |  9,260 →  436 rows | Compression 4.7%
# ⬇ gasoline_world.csv        | DOWNSAMPLE Daily→Monthly |  2,534 →  324 rows | Compression 12.8%
# ⬇ natural_gas.csv           | DOWNSAMPLE Daily→Monthly |  6,437 →  309 rows | Compression 4.8%
# ⬇ gold.csv                  | DOWNSAMPLE Daily→Monthly |  6,431 →  309 rows | Compression 4.8%
# ⬇ silver.csv                | DOWNSAMPLE Daily→Monthly |  6,433 →  309 rows | Compression 4.8%
# ⬇ VNINDEX.csv               | DOWNSAMPLE Daily→Monthly |  6,240 →  309 rows | Compression 5.0%
# ⬇ VN30.csv                  | DOWNSAMPLE Daily→Monthly |  4,290 →  207 rows | Compression 4.8%
# ⬇ HNX.csv                   | DOWNSAMPLE Daily→Monthly |  5,071 →  249 rows | Compression 4.9%
# ⬇ UPCOM.csv                 | DOWNSAMPLE Daily→Monthly |  4,177 →  202 rows | Compression 4.8%
# ⬇ NASDAQ.csv                | DOWNSAMPLE Daily→Monthly | 13,916 →  663 rows | Compression 4.8%
# ⬇ S&P500.csv                | DOWNSAMPLE Daily→Monthly | 24,690 → 1,181 rows | Compression 4.8%
# ⬇ DAX.csv                   | DOWNSAMPLE Daily→Monthly |  9,683 →  461 rows | Compression 4.8%
# ⬇ DOWJONES.csv              | DOWNSAMPLE Daily→Monthly |  8,634 →  412 rows | Compression 4.8%
# ⬇ NIKKEI225.csv             | DOWNSAMPLE Daily→Monthly | 15,067 →  736 rows | Compression 4.9%
# ⬇ HANGSENG.csv              | DOWNSAMPLE Daily→Monthly |  9,696 →  473 rows | Compression 4.9%
# ⬇ USDVND.csv                | DOWNSAMPLE Daily→Monthly |  8,264 →  381 rows | Compression 4.6%
#
#  Resample thành công: 25 files
# KEEP_MONTHLY                   |  5 files | Total rows: 1,438 → 1,438 | Total features:   6
# DOWNSAMPLE_DAILY               | 18 files | Total rows: 145,590 → 7,332 | Total features:  18
# UPSAMPLE_QUARTERLY_FFILL       |  2 files | Total rows: 129 → 389 | Total features:   2

# %%
first_file = list(monthly_data.keys())[2]
sample_df = monthly_data[first_file]

print(f"\n📋 SAMPLE RESAMPLED FILE: {first_file}")
print(f"Shape: {sample_df.shape} (rows × columns)")
print(f"\nColumns: {list(sample_df.columns)}")
print(f"\nFirst 10 rows:")
print(sample_df.tail(30))

# Show statistics
print(f"\n📊 STATISTICS:")
print(sample_df.describe())
# Out:
# 📋 SAMPLE RESAMPLED FILE: interest_rate.csv
# Shape: (145, 2) (rows × columns)
#
# Columns: ['date', 'interest_rate']
#
# First 10 rows:
#           date  interest_rate
# 115 2023-11-01           3.69
# 116 2023-12-01            NaN
# 117 2024-01-01            NaN
# 118 2024-02-01           2.75
# 119 2024-03-01           2.86
# 120 2024-04-01           3.97
# 121 2024-05-01            NaN
# 122 2024-06-01            NaN
# 123 2024-07-01           5.63
# 124 2024-08-01           5.81
# 125 2024-09-01            NaN
# 126 2024-10-01           4.53
# 127 2024-11-01           4.95
# 128 2024-12-01            NaN
# 129 2025-01-01            NaN
# 130 2025-02-01            NaN
# 131 2025-03-01            NaN
# 132 2025-04-01           5.52
# 133 2025-05-01            NaN
# 134 2025-06-01            NaN
# 135 2025-07-01           5.01
# 136 2025-08-01           5.46
# 137 2025-09-01            NaN
# 138 2025-10-01           4.90
# 139 2025-11-01            NaN
# 140 2025-12-01            NaN
# 141 2026-01-01            NaN
# 142 2026-02-01           7.29
# 143 2026-03-01           8.39
# 144 2026-04-01           7.83
#
# 📊 STATISTICS:
#                                 date  interest_rate
# count                            145      79.000000
# mean   2020-03-31 23:40:08.275862016       4.200633
# min              2014-04-01 00:00:00       1.200000
# 25%              2017-04-01 00:00:00       3.305000
# 50%              2020-04-01 00:00:00       4.220000
# 75%              2023-04-01 00:00:00       4.795000
# max              2026-04-01 00:00:00       9.430000
# std                              NaN       1.634580

# %%
# Merge tất cả vào trục thời gian chuẩn (Left Join)
merged_on_axis = time_index.copy()

for filename, df in monthly_data.items():
    cols_to_merge = [col for col in df.columns if col != 'date']
    if cols_to_merge:
        merge_df = df[['date'] + cols_to_merge].copy()
        
        rows_before = len(merged_on_axis)
        merged_on_axis = merged_on_axis.merge(merge_df, on='date', how='left')
        rows_after = len(merged_on_axis)
        
        print(f"  ✓ {filename:25} | {len(cols_to_merge):2d} features added | {rows_before} → {rows_after} rows")

print(f"Merged dataset shape: {merged_on_axis.shape}")
print(f"Date range: {merged_on_axis['date'].min().date()} to {merged_on_axis['date'].max().date()}")
# Out:
#   ✓ cpi_mom_processed.csv     |  2 features added | 360 → 360 rows
#   ✓ core_inflation_rate.csv   |  1 features added | 360 → 360 rows
#   ✓ interest_rate.csv         |  1 features added | 360 → 360 rows
#   ✓ ppi_qoq.csv               |  1 features added | 360 → 360 rows
#   ✓ m2.csv                    |  1 features added | 360 → 360 rows
#   ✓ broad_money.csv           |  1 features added | 360 → 360 rows
#   ✓ policy_rate.csv           |  1 features added | 360 → 360 rows
#   ✓ gdp.csv                   |  1 features added | 360 → 360 rows
#   ✓ brent.csv                 |  1 features added | 360 → 360 rows
#   ✓ wti.csv                   |  1 features added | 360 → 360 rows
#   ✓ gasoline_world.csv        |  1 features added | 360 → 360 rows
#   ✓ natural_gas.csv           |  1 features added | 360 → 360 rows
#   ✓ gold.csv                  |  1 features added | 360 → 360 rows
#   ✓ silver.csv                |  1 features added | 360 → 360 rows
#   ✓ VNINDEX.csv               |  1 features added | 360 → 360 rows
#   ✓ VN30.csv                  |  1 features added | 360 → 360 rows
#   ✓ HNX.csv                   |  1 features added | 360 → 360 rows
#   ✓ UPCOM.csv                 |  1 features added | 360 → 360 rows
#   ✓ NASDAQ.csv                |  1 features added | 360 → 360 rows
#   ✓ S&P500.csv                |  1 features added | 360 → 360 rows
#   ✓ DAX.csv                   |  1 features added | 360 → 360 rows
#   ✓ DOWJONES.csv              |  1 features added | 360 → 360 rows
#   ✓ NIKKEI225.csv             |  1 features added | 360 → 360 rows
#   ✓ HANGSENG.csv              |  1 features added | 360 → 360 rows
#   ✓ USDVND.csv                |  1 features added | 360 → 360 rows
# Merged dataset shape: (360, 27)
# Date range: 1995-01-01 to 2024-12-01

# %%
merged_on_axis.head()
# Out:
#         date  cpi_mom_processed_cpi  cpi_mom_processed_inflation  \
# 0 1995-01-01                  103.8                          3.8
# 1 1995-02-01                  103.4                          3.4
# 2 1995-03-01                  100.2                          0.2
# 3 1995-04-01                  101.0                          1.0
# 4 1995-05-01                  101.8                          1.8
#
#    core_inflation_rate  interest_rate  ppi_qoq  m2  broad_money  policy_rate  \
# 0                  NaN            NaN      NaN NaN        3.567         10.8
# 1                  NaN            NaN      NaN NaN        3.303         10.8
# 2                  NaN            NaN      NaN NaN        3.495         10.8
# 3                  NaN            NaN      NaN NaN        3.434         10.8
# 4                  NaN            NaN      NaN NaN        3.247         10.8
#
#    gdp  ...  VN30  HNX  UPCOM      NASDAQ      S&P500          DAX  \
# 0  NaN  ...   NaN  NaN    NaN  755.200012  470.420013  2024.819946
# 1  NaN  ...   NaN  NaN    NaN  793.729980  487.390015  2097.850098
# 2  NaN  ...   NaN  NaN    NaN  817.210022  500.709991  1914.689941
# 3  NaN  ...   NaN  NaN    NaN  843.979980  514.710022  2017.949951
# 4  NaN  ...   NaN  NaN    NaN  864.580017  533.400024  2099.949951
#
#       DOWJONES     NIKKEI225     HANGSENG   USDVND
# 0  3843.860107  18649.820312  7342.700195  11039.0
# 1  4011.050049  17053.429688  8327.500000  11050.0
# 2  4157.689941  16139.950195  8587.700195  11045.0
# 3  4321.270020  16806.750000  8361.000000  11041.0
# 4  4465.140137  15436.790039  9407.400391  11045.0
#
# [5 rows x 27 columns]

# %%
# #Imputation với Forward Fill
missing_before = merged_on_axis.isnull().sum().sum()
print(f"  Missing values BEFORE: {missing_before:,}")

# Forward fill only (không back fill để không tạo giá trị tương lai)
merged_on_axis = merged_on_axis.fillna(method='ffill')
# back fill chỉ cho những tháng đầu tiên nếu có null ở đó, vì không có dữ liệu trước đó để ffill
merged_on_axis = merged_on_axis.fillna(method='bfill')
missing_after = merged_on_axis.isnull().sum().sum()
print(f"  Missing values AFTER ffill: {missing_after:,}")

# Show remaining nulls by column
null_cols = merged_on_axis.isnull().sum()
null_cols = null_cols[null_cols > 0].sort_values(ascending=False)

if len(null_cols) > 0:
    print("Remaining nulls by column (at start of time series):")
    for col, count in null_cols.items():
        null_pct = (count / len(merged_on_axis) * 100)
        print(f"{col:40} | {count:4d} nulls ({null_pct:.1f}%)")
else:
    print("\nNo remaining null values!")

print(f"Final dataset: {merged_on_axis.shape[0]} months × {merged_on_axis.shape[1]} columns")
print(f"Data completeness: {(1 - missing_after / (merged_on_axis.shape[0] * merged_on_axis.shape[1])) * 100:.1f}%")
# Out:
#   Missing values BEFORE: 2,007
#   Missing values AFTER ffill: 0
#
# No remaining null values!
# Final dataset: 360 months × 27 columns
# Data completeness: 100.0%

# %%
null_percentage = (merged_on_axis.isnull().sum() / len(merged_on_axis) * 100)
cols_to_drop = null_percentage[null_percentage > 90].index.tolist()

if len(cols_to_drop) > 0:
    print(f"Xóa {len(cols_to_drop)} cột có > 90% null:")
    for col in cols_to_drop:
        null_pct = null_percentage[col]
        print(f"  ✗ {col:40} | {null_pct:.1f}% null → DROP")
    
    merged_on_axis = merged_on_axis.drop(columns=cols_to_drop)
    print(f"\n✓ Sau khi xóa: {merged_on_axis.shape}")
else:
    print("✓ Không có cột nào cần xóa (tất cả ≤ 90% null)")

print(f"\n📊 CẬP NHẬT NULL STATS:")
missing_after_cleanup = merged_on_axis.isnull().sum().sum()
print(f"  Total nulls: {missing_after_cleanup:,}")
print(f"  Data completeness: {(1 - missing_after_cleanup / (merged_on_axis.shape[0] * merged_on_axis.shape[1])) * 100:.1f}%")
# Out:
# ✓ Không có cột nào cần xóa (tất cả ≤ 90% null)
#
# 📊 CẬP NHẬT NULL STATS:
#   Total nulls: 0
#   Data completeness: 100.0%

# %%
# điền null của ppi_qoq bằng giá trị đầu tiên có giá trị (do nó chỉ có 1 giá trị mỗi quý, nên sẽ lặp lại giá trị đó cho các tháng trong quý)
if 'ppi_qoq' in merged_on_axis.columns:
    first_valid = merged_on_axis['ppi_qoq'].first_valid_index()
    if first_valid is not None:
        first_value = merged_on_axis.loc[first_valid, 'ppi_qoq']
        merged_on_axis['ppi_qoq'] = merged_on_axis['ppi_qoq'].fillna(first_value)
        print(f"✓ Điền null của 'ppi_qoq' bằng giá trị đầu tiên: {first_value}")
    else:
        print("⚠ Không tìm thấy giá trị hợp lệ nào trong 'ppi_qoq' để điền null.")
# Out:
# ✓ Điền null của 'ppi_qoq' bằng giá trị đầu tiên: -0.73

# %%
merged_on_axis.to_csv(os.path.join(data_processed_dir, 'merged_monthly_data.csv'), index=False)

# %%
merged_on_axis
# Out:
#           date  cpi_mom_processed_cpi  cpi_mom_processed_inflation  \
# 0   1995-01-01                 103.80                         3.80
# 1   1995-02-01                 103.40                         3.40
# 2   1995-03-01                 100.20                         0.20
# 3   1995-04-01                 101.00                         1.00
# 4   1995-05-01                 101.80                         1.80
# ..         ...                    ...                          ...
# 355 2024-08-01                 100.00                         0.00
# 356 2024-09-01                 100.29                         0.29
# 357 2024-10-01                 100.33                         0.33
# 358 2024-11-01                 100.13                         0.13
# 359 2024-12-01                 100.29                         0.29
#
#      core_inflation_rate  interest_rate  ppi_qoq          m2  broad_money  \
# 0                   2.20           3.85    -0.73   1748226.0        3.567
# 1                   2.20           3.85    -0.73   1748226.0        3.303
# 2                   2.20           3.85    -0.73   1748226.0        3.495
# 3                   2.20           3.85    -0.73   1748226.0        3.434
# 4                   2.20           3.85    -0.73   1748226.0        3.247
# ..                   ...            ...      ...         ...          ...
# 355                 2.53           5.81     0.07  16658293.0        6.576
# 356                 2.54           5.81     0.07  16949072.0        6.576
# 357                 2.68           4.53    -0.23  17107320.0        6.576
# 358                 2.77           4.95    -0.23  17301843.0        6.576
# 359                 2.85           4.95    -0.23  17914566.0        6.576
#
#      policy_rate           gdp  ...     VN30     HNX  UPCOM        NASDAQ  \
# 0           10.8  4.344780e+05  ...   300.48   99.20  77.67    755.200012
# 1           10.8  4.344780e+05  ...   300.48   99.20  77.67    793.729980
# 2           10.8  4.344780e+05  ...   300.48   99.20  77.67    817.210022
# 3           10.8  4.344780e+05  ...   300.48   99.20  77.67    843.979980
# 4           10.8  4.344780e+05  ...   300.48   99.20  77.67    864.580017
# ..           ...           ...  ...      ...     ...    ...           ...
# 355          4.5  3.757535e+06  ...  1331.52  237.56  94.17  17713.619141
# 356          4.5  3.757535e+06  ...  1352.56  234.91  93.56  18189.169922
# 357          4.5  4.320246e+06  ...  1338.60  226.36  92.38  18095.150391
# 358          4.5  4.320246e+06  ...  1311.26  224.64  92.74  19218.169922
# 359          4.5  4.320246e+06  ...  1344.75  227.43  95.06  19310.789062
#
#           S&P500           DAX      DOWJONES     NIKKEI225      HANGSENG  \
# 0     470.420013   2024.819946   3843.860107  18649.820312   7342.700195
# 1     487.390015   2097.850098   4011.050049  17053.429688   8327.500000
# 2     500.709991   1914.689941   4157.689941  16139.950195   8587.700195
# 3     514.710022   2017.949951   4321.270020  16806.750000   8361.000000
# 4     533.400024   2099.949951   4465.140137  15436.790039   9407.400391
# ..           ...           ...           ...           ...           ...
# 355  5648.399902  18906.919922  41563.078125  38647.750000  17989.070312
# 356  5762.479980  19324.929688  42330.148438  37919.550781  21133.679688
# 357  5705.450195  19077.539062  41763.460938  39081.250000  20317.330078
# 358  6032.379883  19626.449219  44910.648438  38208.031250  19423.609375
# 359  5881.629883  19909.140625  42544.218750  39894.539062  20059.949219
#
#       USDVND
# 0    11039.0
# 1    11050.0
# 2    11045.0
# 3    11041.0
# 4    11045.0
# ..       ...
# 355  24860.0
# 356  24555.0
# 357  25270.0
# 358  25344.0
# 359  25480.0
#
# [360 rows x 27 columns]

# %%
# # Lấy đầy đủ tháng + last của tháng 
# monthly_data = {}
# agg_report = []

# for filename, df in loaded_data.items():
#     try:
#         df_agg = df.copy()
#         df_agg['year_month'] = df_agg['date'].dt.to_period('M')
        
#         # Get value columns
#         value_cols = [col for col in df_agg.columns if col not in ['date', 'year_month']]
        
#         # Aggregate (last value of month)
#         agg_dict = {col: 'last' for col in value_cols}
#         monthly = df_agg.groupby('year_month').agg(agg_dict).reset_index()
#         monthly['date'] = monthly['year_month'].dt.to_timestamp()
#         monthly = monthly.drop('year_month', axis=1)
        
#         monthly_data[filename] = monthly
        
#         compression_ratio = (len(monthly) / len(df)) * 100
#         agg_report.append({
#             'Filename': filename,
#             'Original': len(df),
#             'Monthly': len(monthly),
#             'Compression': f"{compression_ratio:.1f}%"
#         })
        
#         print(f"  ✓ {filename:25} | {len(df):6,} rows → {len(monthly):6,} months ({compression_ratio:.1f}% compression)")
    
#     except Exception as e:
#         print(f"  ✗ {filename:25} | ERROR: {str(e)[:40]}")

# print(f"\n✓ Gộp thành công: {len(monthly_data)} files")

# # Show summary
# agg_df = pd.DataFrame(agg_report)
# print(f"\nTổng rows ban đầu: {agg_df['Original'].sum():,}")
# print(f"Tổng tháng sau gộp: {agg_df['Monthly'].sum():,}")

# %% [markdown]
# ## BƯỚC 4: Merge Tất Cả Dữ Liệu

# %%
# print("\n[STEP 3] MERGE TẤT CẢ DỮ LIỆU THEO NGÀY")
# print("="*100)

# # Check CPI data
# if 'cpi_mom.csv' not in monthly_data:
#     print("ERROR: CPI data not found!")
#     raise ValueError("CPI data (cpi_mom.csv) required as base")

# # Start with CPI as base
# cpi_df = monthly_data['cpi_mom.csv'].copy()
# value_col = [col for col in cpi_df.columns if col != 'date'][0]
# base = cpi_df[['date', value_col]].copy()
# base = base.rename(columns={value_col: 'CPI'})
# base = base.sort_values('date').reset_index(drop=True)

# print(f"  Base dataset (CPI): {len(base)} rows from {base['date'].min().date()} to {base['date'].max().date()}")

# # Merge other data
# merged_data = base.copy()
# merge_report = []

# for filename, df in monthly_data.items():
#     if filename != 'cpi_mom.csv':
#         cols_to_merge = [col for col in df.columns if col != 'date']
#         if cols_to_merge:
#             merge_df = df[['date'] + cols_to_merge].copy()
#             rows_before = len(merged_data)
#             merged_data = merged_data.merge(merge_df, on='date', how='outer')
#             rows_after = len(merged_data)
            
#             merge_report.append({
#                 'Source': filename,
#                 'New_Rows': rows_after - rows_before,
#                 'Total_Rows': rows_after,
#                 'Columns_Added': len(cols_to_merge)
#             })
            
#             print(f"  ✓ {filename:25} | +{rows_after - rows_before:4,} rows → {rows_after:6,} total")

# merged_data = merged_data.sort_values('date').reset_index(drop=True)

# print(f"\n✓ Merged dataset: {len(merged_data)} rows × {len(merged_data.columns)} columns")
# print(f"✓ Date range: {merged_data['date'].min().date()} to {merged_data['date'].max().date()}")

# %% [markdown]
# ## BƯỚC 5: Xử Lý Missing Values

# %%
# print("\n[STEP 4] XỬ LÝ MISSING VALUES")
# print("="*100)

# # Filter to CPI data range
# cpi_available = merged_data[merged_data['CPI'].notna()].copy()
# cpi_start = cpi_available['date'].min()
# cpi_end = cpi_available['date'].max()

# print(f"  CPI data range: {cpi_start.date()} to {cpi_end.date()}")

# # Filter to CPI period
# merged_data = merged_data[(merged_data['date'] >= cpi_start) & 
#                           (merged_data['date'] <= cpi_end)].copy()

# print(f"  Filtered to CPI range: {len(merged_data)} rows")

# # Check missing values
# missing_before = merged_data.isnull().sum().sum()
# print(f"  Missing values BEFORE: {missing_before:,}")

# # Fill missing values
# merged_data = merged_data.fillna(method='ffill').fillna(method='bfill')

# missing_after = merged_data.isnull().sum().sum()
# print(f"  Missing values AFTER: {missing_after:,}")

# # Drop all NaN rows
# merged_data = merged_data.dropna(how='all', subset=merged_data.columns[1:])

# print(f"\n✓ Final rows after cleaning: {len(merged_data)}")
# print(f"✓ Data completeness: {(1 - missing_after / (merged_data.shape[0] * merged_data.shape[1])) * 100:.1f}%")

# %% [markdown]
# ## BƯỚC 6: Feature Engineering

# %%
final_data = merged_on_axis.copy()

print(f"  Final dataset for modeling: {len(final_data)} months")
print(f"  Date range: {final_data['date'].min().date()} to {final_data['date'].max().date()}")

final_data['year'] = final_data['date'].dt.year
final_data['month'] = final_data['date'].dt.month
final_data['quarter'] = final_data['date'].dt.quarter

print(f"  ✓ Added temporal features (year, month, quarter)")
print(f"\n  Final shape: {final_data.shape}")
print(f"  Columns: {len(final_data.columns)}")
# Out:
#   Final dataset for modeling: 360 months
#   Date range: 1995-01-01 to 2024-12-01
#   ✓ Added temporal features (year, month, quarter)
#
#   Final shape: (360, 30)
#   Columns: 30

# %%
final_data.head()
# Out:
#         date  cpi_mom_processed_cpi  cpi_mom_processed_inflation  \
# 0 1995-01-01                  103.8                          3.8
# 1 1995-02-01                  103.4                          3.4
# 2 1995-03-01                  100.2                          0.2
# 3 1995-04-01                  101.0                          1.0
# 4 1995-05-01                  101.8                          1.8
#
#    core_inflation_rate  interest_rate  ppi_qoq         m2  broad_money  \
# 0                  2.2           3.85    -0.73  1748226.0        3.567
# 1                  2.2           3.85    -0.73  1748226.0        3.303
# 2                  2.2           3.85    -0.73  1748226.0        3.495
# 3                  2.2           3.85    -0.73  1748226.0        3.434
# 4                  2.2           3.85    -0.73  1748226.0        3.247
#
#    policy_rate      brent  ...      NASDAQ      S&P500          DAX  \
# 0         10.8  77.050003  ...  755.200012  470.420013  2024.819946
# 1         10.8  77.050003  ...  793.729980  487.390015  2097.850098
# 2         10.8  77.050003  ...  817.210022  500.709991  1914.689941
# 3         10.8  77.050003  ...  843.979980  514.710022  2017.949951
# 4         10.8  77.050003  ...  864.580017  533.400024  2099.949951
#
#       DOWJONES     NIKKEI225     HANGSENG   USDVND  year  month  quarter
# 0  3843.860107  18649.820312  7342.700195  11039.0  1995      1        1
# 1  4011.050049  17053.429688  8327.500000  11050.0  1995      2        1
# 2  4157.689941  16139.950195  8587.700195  11045.0  1995      3        1
# 3  4321.270020  16806.750000  8361.000000  11041.0  1995      4        2
# 4  4465.140137  15436.790039  9407.400391  11045.0  1995      5        2
#
# [5 rows x 29 columns]

# %% [markdown]
# ## BƯỚC 7: Kiểm Tra Chất Lượng Dữ Liệu

# %%
print("\n[STEP 6] KIỂM TRA CHẤT LƯỢNG DỮ LIỆU")
print("="*100)

print(f"  Final dataset shape: {final_data.shape}")
print(f"  Date range: {final_data['date'].min().date()} to {final_data['date'].max().date()}")
print(f"  Total columns: {len(final_data.columns)}")
print(f"  Numeric columns: {len(final_data.select_dtypes(include=[np.number]).columns)}")
print(f"  Missing values: {final_data.isnull().sum().sum()}")

print("\n📋 CHI TIẾT COLUMNS:")
print("-" * 100)
print(f"{'Column':<30} {'Type':<15} {'Missing':<10} {'Min':<15} {'Max':<15}")
print("-" * 100)

for col in final_data.columns[:15]:  # Show first 15 columns
    dtype = str(final_data[col].dtype)
    missing = final_data[col].isnull().sum()
    
    if final_data[col].dtype in ['float64', 'int64']:
        min_val = f"{final_data[col].min():.2f}"
        max_val = f"{final_data[col].max():.2f}"
    else:
        min_val = str(final_data[col].min())[:15]
        max_val = str(final_data[col].max())[:15]
    
    print(f"{col:<30} {dtype:<15} {missing:<10} {min_val:<15} {max_val:<15}")
# Out:
# [STEP 6] KIỂM TRA CHẤT LƯỢNG DỮ LIỆU
# ====================================================================================================
#   Final dataset shape: (360, 30)
#   Date range: 1995-01-01 to 2024-12-01
#   Total columns: 30
#   Numeric columns: 29
#   Missing values: 0
#
# 📋 CHI TIẾT COLUMNS:
# ----------------------------------------------------------------------------------------------------
# Column                         Type            Missing    Min             Max
# ----------------------------------------------------------------------------------------------------
# date                           datetime64[ns]  0          1995-01-01 00:0 2024-12-01 00:0
# cpi_mom_processed_cpi          float64         0          98.46           103.91
# cpi_mom_processed_inflation    float64         0          -1.54           3.91
# core_inflation_rate            float64         0          0.49            5.21
# interest_rate                  float64         0          1.20            9.43
# ppi_qoq                        float64         0          -1.66           2.10
# m2                             float64         0          1748226.00      17914566.00
# broad_money                    float64         0          2.62            10.79
# policy_rate                    float64         0          4.00            15.00
# gdp                            float64         0          192958.00       5270906.00
# brent                          float64         0          22.74           139.83
# wti                            float64         0          11.22           140.00
# gasoline_world                 float64         0          0.51            2.73
# natural_gas                    float64         0          1.64            13.92
# gold                           float64         0          257.90          2738.30

# %% [markdown]
# ## BƯỚC 8: Lưu Unified Dataset

# %%
print("\n[STEP 7] SAVING UNIFIED DATASET")
print("="*100)

# Save only the main unified dataset
output_file = os.path.join(data_processed_dir, 'cpi_02_06.csv')
final_data.to_csv(output_file, index=False, encoding='utf-8')
file_size = os.path.getsize(output_file) / 1024  # KB

print(f"  ✓ Saved: cpi_02_06.csv ({len(final_data)} rows, {file_size:.1f} KB)")
print(f"  📁 Location: {output_file}")
# Out:
# [STEP 7] SAVING UNIFIED DATASET
# ====================================================================================================
#   ✓ Saved: cpi_02_06.csv (360 rows, 109.7 KB)
#   📁 Location: d:\Nam4-HK1\KLTN\Vietnam_economic_lakehouse\model_test\data\processed\cpi_02_06.csv

# %% [markdown]
# ## BƯỚC 9: Tổng Kết & Thống Kê

# %% [markdown]
# ## Kiểm Tra Lại Kết Quả

# %%
# Verify saved file
if os.path.exists(output_file):
    file_size = os.path.getsize(output_file) / (1024 * 1024)  # MB
    verify_df = pd.read_csv(output_file, nrows=5)
    
    print("✅ VERIFICATION SUCCESSFUL")
    print(f"  ✓ File exists: {output_file}")
    print(f"  ✓ File size: {file_size:.2f} MB")
    print(f"  ✓ Rows: {len(pd.read_csv(output_file))}")
    print(f"  ✓ Columns: {len(verify_df.columns)}")
    print(f"  ✓ Date range: {verify_df['date'].iloc[0]} to {verify_df['date'].iloc[-1]}")
    print("\n✓ Ready for STEP 1: Data Preparation & Exploration")
else:
    print("❌ ERROR: File not saved")
# Out:
# ✅ VERIFICATION SUCCESSFUL
#   ✓ File exists: d:\Nam4-HK1\KLTN\Vietnam_economic_lakehouse\model_test\data\processed\cpi_02_06.csv
#   ✓ File size: 0.11 MB
#   ✓ Rows: 360
#   ✓ Columns: 30
#   ✓ Date range: 1995-01-01 to 1995-05-01
#
# ✓ Ready for STEP 1: Data Preparation & Exploration
